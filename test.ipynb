# %%
import pandas as pd

# %%
polls_df = pd.read_csv("polls.csv").set_index("id")
polls_df
# Out:
#                              poll  option1        option2       option3  \
# id
# 1                     Hello_world        A              B             C
# 2                     Hello_world        A              B             C
# 3                     Hello_world        A              B             C
# 4                     Hello_world        A              B             C
# 5                          aaysuh     kdfj             jf           ire
# 6                             hew      ehw            nen          hbri
# 7                            New1        a              b             c
# 8                       Best Game        a              b             c
# 9                      Best Movie   Batman  Jurassic Park  Interstellar
# 10                            NaN      NaN            NaN           NaN
# 11         Ashish bhai kab ayenge       11             12            13
# 12  Which Python Project to builf      NaN            NaN           NaN
# ...

# %%
id='2'
poll = polls_df.loc[int(id)]
poll.values[0]
# Out:
# 'Hello_world'

# %% [markdown]
# # Logic

# %%
columns = ['poll_id', 'poll_name', 'poll_option_no', 'poll_option', 'poll_vote']
df = pd.DataFrame(columns=columns)
df.to_csv('poll_test.csv')
df
# Out:
# Empty DataFrame
# Columns: [poll_id, poll_name, poll_option_no, poll_option, poll_vote]
# Index: []

# %%
new_df = pd.read_csv('poll_test.csv')
new_df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, poll_id, poll_name, poll_option_no, poll_option, poll_vote]
# Index: []

# %%
poll = 'Best Game'
dict = {1: 'a', 2: 'b', 3: 'c', 4: 'd', 5: 'e'}
df = pd.DataFrame(dict, index=['Values']).transpose().reset_index()
df.columns = ['poll_option_no', 'poll_option']
df['poll_name'] = poll
df['poll_vote'] = 0
max_df = pd.read_csv('poll_test.csv')
try:
    df['poll_id'] = max(max_df['poll_id']) + 1
except:
    df['poll_id'] = 1
df = df[['poll_id','poll_name','poll_option_no', 'poll_option','poll_vote']]
df.to_csv('poll_test.csv', mode='a', header=False)
df
# Out:
#    poll_id  poll_name  poll_option_no poll_option  poll_vote
# 0        1  Best Game               1           a          0
# 1        1  Best Game               2           b          0
# 2        1  Best Game               3           c          0
# 3        1  Best Game               4           d          0
# 4        1  Best Game               5           e          0

# %%
pd.read_csv('poll_test.csv')
# Out:
#    Unnamed: 0  poll_id  poll_name  poll_option_no poll_option  poll_vote
# 0           0        1  Best Game               1           a          0
# 1           1        1  Best Game               2           b          0
# 2           2        1  Best Game               3           c          0
# 3           3        1  Best Game               4           d          0
# 4           4        1  Best Game               5           e          0

# %%
max_df = pd.read_csv('poll_test.csv')
max_df
max(max_df['poll_id'])
# Out:
# 1

# %%
poll = 'Next Game'
dict = {1: 'a', 2: 'b', 3: 'c', 4: 'd', 5: 'e'}
df2 = pd.DataFrame(dict, index=['Values']).transpose().reset_index()
df2.columns = ['poll_option_no', 'poll_option']
df2['poll_name'] = poll
df2['poll_vote'] = 0
max_df = pd.read_csv('poll_test.csv')
try:
    df2['poll_id'] = max(max_df['poll_id']) + 1
except:
    df2['poll_id'] = 1
df2 = df2[['poll_id','poll_name','poll_option_no', 'poll_option','poll_vote']]
df2.to_csv('poll_test.csv', mode='a', header=False)
df2
# Out:
#    poll_id  poll_name  poll_option_no poll_option  poll_vote
# 0        2  Next Game               1           a          0
# 1        2  Next Game               2           b          0
# 2        2  Next Game               3           c          0
# 3        2  Next Game               4           d          0
# 4        2  Next Game               5           e          0

# %%
df4 = pd.read_csv('poll_test.csv')
# df4.reset_index(drop=True, inplace=True)
# df4.drop(columns=['Unnamed: 0'],axis=1, inplace=True)
df4
# Out:
#    Unnamed: 0  poll_id  poll_name  poll_option_no poll_option  poll_vote
# 0           0        1  Best Game               1           a          0
# 1           1        1  Best Game               2           b          0
# 2           2        1  Best Game               3           c          0
# 3           3        1  Best Game               4           d          0
# 4           4        1  Best Game               5           e          0
# 5           0        2  Next Game               1           a          0
# 6           1        2  Next Game               2           b          0
# 7           2        2  Next Game               3           c          0
# 8           3        2  Next Game               4           d          0
# 9           4        2  Next Game               5           e          0

# %%
poll = 'Next2Next Game'
dict = {1: 'a', 2: 'b', 3: 'c', 4: 'd', 5: 'e'}
df2 = pd.DataFrame(dict, index=['Values']).transpose().reset_index()
df2.columns = ['poll_option_no', 'poll_option']
df2['poll_name'] = poll
df2['poll_vote'] = 0
max_df = pd.read_csv('poll_test.csv')
try:
    df2['poll_id'] = max(max_df['poll_id']) + 1
except:
    df2['poll_id'] = 1
df2 = df2[['poll_id','poll_name','poll_option_no', 'poll_option','poll_vote']]
df2.to_csv('poll_test.csv', mode='a', header=False)
df2
# Out:
#    poll_id       poll_name  poll_option_no poll_option  poll_vote
# 0        3  Next2Next Game               1           a          0
# 1        3  Next2Next Game               2           b          0
# 2        3  Next2Next Game               3           c          0
# 3        3  Next2Next Game               4           d          0
# 4        3  Next2Next Game               5           e          0

# %%
df4 = pd.read_csv('poll_test.csv')
# df4.reset_index(drop=True, inplace=True)
df4.drop(columns=['Unnamed: 0'],axis=1, inplace=True)
df4
# Out:
#     poll_id  poll_name  poll_option_no poll_option  poll_vote
# 0         1  Best Game               1           a          0
# 1         1  Best Game               2           b          0
# 2         1  Best Game               3           g          0
# 3         1  Best Game               4           d          0
# 4         1  Best Game               5           r          0
# 5         1  Best Game               6           y          0
# 6         2  Best Game               1         aBb          0
# 7         2  Best Game               2           B          0
# 8         2  Best Game               3           B          0
# 9         2  Best Game               4           B          0
# 10        2  Best Game               5           B          0
# 11        2  Best Game               6           B          0
# 12        2  Best Game               7           B          0
# 13        2  Best Game               8           B          0
# ...

# %%
df = pd.read_csv('poll_test.csv')
df.drop(columns=['Unnamed: 0'],axis=1, inplace=True)
df.groupby('poll_id').min()
# poll2
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
for key, value in df.iterrows():
    print(type(value['poll_id']))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
poll = polls_df.loc[int(id)]

# %%
poll
# Out:
# poll       Hello_world
# option1              A
# option2              B
# option3              C
# vote1                1
# vote2                0
# vote3                0
# Name: 2, dtype: object

# %%
for key, value in poll2.iterrows():
    # print(key)
    print(value['poll_name'])
# Out:
# Best Game
# Best Game

# %%
df
# Out:
#     poll_id  poll_name  poll_option_no poll_option  poll_vote
# 0         1  Best Game               1           a          0
# 1         1  Best Game               2           b          0
# 2         1  Best Game               3           g          0
# 3         1  Best Game               4           d          0
# 4         1  Best Game               5           r          0
# 5         1  Best Game               6           y          0
# 6         2  Best Game               1         aBb          0
# 7         2  Best Game               2           B          0
# 8         2  Best Game               3           B          0
# 9         2  Best Game               4           B          0
# 10        2  Best Game               5           B          0
# 11        2  Best Game               6           B          0
# 12        2  Best Game               7           B          0
# 13        2  Best Game               8           B          0
# ...

# %%
poll = df[df['poll_id']==1]

# %%
poll['poll_option']
# Out:
# 0    a
# 1    b
# 2    g
# 3    d
# 4    r
# 5    y
# Name: poll_option, dtype: object

# %%
poll['poll_name'][0]
# Out:
# 'Best Game'

# %%
for key, value in poll.iterrows():
    print(value['poll_option_no'])
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
poll['poll_id'][0]
# Out:
# 1

# %%
poll.id[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/0h/1ykftl_53n5gzxr93wfqj35c0000gn/T/ipykernel_20999/384107660.py in ?()
# ----> 1 poll.id[0]
#
# /opt/homebrew/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'id'

# %%
poll[(poll['poll_id']==1) & (poll['poll_option_no']==1)]['poll_vote'] += 1
# Out:
# /var/folders/0h/1ykftl_53n5gzxr93wfqj35c0000gn/T/ipykernel_20999/1553507245.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poll[(poll['poll_id']==1) & (poll['poll_option_no']==1)]['poll_vote'] += 1

# %% [markdown]
# poll: This is the DataFrame you are working with.
#
# .loc[]: This is the loc accessor used for label-based indexing.
#
# [(poll['poll_id'] == 1) & (poll['poll_option_no'] == 1), 'poll_vote']: This part consists of two components:
#
# (poll['poll_id'] == 1) & (poll['poll_option_no'] == 1): This is a boolean condition that is applied to the rows of the DataFrame. It checks if both 'poll_id' is equal to 1 and 'poll_option_no' is equal to 1.
#
# 'poll_vote': This specifies the column you are interested in, which is 'poll_vote'.
#
# += 1: This part increments the values in the 'poll_vote' column by 1 for the rows that satisfy the condition.

# %%
poll.loc[(poll['poll_id'] == 1) & (poll['poll_option_no'] == 1), 'poll_vote'] += 1

# %%
poll
# Out:
#    poll_id  poll_name  poll_option_no poll_option  poll_vote
# 0        1  Best Game               1           a          1
# 1        1  Best Game               2           b          0
# 2        1  Best Game               3           g          0
# 3        1  Best Game               4           d          0
# 4        1  Best Game               5           r          0
# 5        1  Best Game               6           y          0

# %%
polls_df2 = df.groupby('poll_id').max().reset_index()

# %%
polls_df2
# Out:
#    poll_id  poll_name  poll_option_no poll_option  poll_vote
# 0        1  Best Game               6           y          0
# 1        2  Best Game              10         aBb          0

# %%
df = pd.read_csv('poll_test.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      23 non-null     int64
#  1   poll_id         23 non-null     int64
#  2   poll_name       23 non-null     object
#  3   poll_option_no  23 non-null     int64
#  4   poll_option     22 non-null     object
#  5   poll_vote       23 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 1.2+ KB

# %%
for key, value in df.iterrows():
    print(type(value['poll_option_no']))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
    df = pd.read_csv('poll_test.csv')
    df.drop(columns=['Unnamed: 0'],axis=1, inplace=True)
    polls_df2 = df.groupby('poll_id').max().reset_index()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
print(df.dtypes)
# Out:
# poll_id            int64
# poll_name         object
# poll_option_no     int64
# poll_option       object
# poll_vote          int64
# dtype: object

# %%
df['poll_vote'] = pd.to_numeric(df['poll_vote'], errors='coerce')
polls_df2 = df.groupby('poll_id').max().reset_index()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
polls_df2 = df.groupby('poll_id').agg('max').reset_index()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
# Convert relevant columns to numeric
numeric_columns = ['poll_vote']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Group by 'poll_id' and apply max to each numeric column
polls_df2 = df.groupby('poll_id').agg('max').reset_index()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
poll['poll_id'][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/aayushgupta/Desktop/VS Git/Working/Polling App/test.ipynb Cell 39 line 1
# ----> <a href='vscode-notebook-cell:/Users/aayushgupta/Desktop/VS%20Git/Working/Polling%20App/test.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> poll['poll_id'][0]
#
# NameError: name 'poll' is not defined

# %%
    df = pd.read_csv('poll_test.csv')
    df.drop(columns=['Unnamed: 0'],axis=1, inplace=True)
    polls_df2 = df.groupby('poll_id').max().reset_index()

# %%
polls_df2
# Out:
#    poll_id  poll_name  poll_option_no poll_option  poll_vote
# 0        1  Best Game               6           y          0
# 1        2  Best Game               9         aBb          0
# 2        3  Best Game               2           b          0
# 3        4  Best Game               6           g          0
# 4        5       Modi               3           c          0

# %%
id=2

# %%
polls_df = pd.read_csv("poll_test.csv")

poll = polls_df[polls_df['poll_id']==int(id)]
poll
# Out:
#     Unnamed: 0  poll_id  poll_name  poll_option_no poll_option  poll_vote
# 6            0        2  Best Game               1         aBb          0
# 7            1        2  Best Game               2           B          0
# 8            2        2  Best Game               3           B          0
# 9            3        2  Best Game               4           B          0
# 10           4        2  Best Game               5           B          0
# 11           5        2  Best Game               6           B          0
# 12           6        2  Best Game               7           B          0
# 13           7        2  Best Game               8           B          0
# 14           8        2  Best Game               9          BB          0

# %%
polls_df = pd.read_csv("poll_test.csv")
poll = polls_df[polls_df['poll_id']==int(id)]

# %%
poll
# Out:
#     Unnamed: 0  poll_id  poll_name  poll_option_no poll_option  poll_vote
# 6            0        2  Best Game               1         aBb          0
# 7            1        2  Best Game               2           B          0
# 8            2        2  Best Game               3           B          0
# 9            3        2  Best Game               4           B          0
# 10           4        2  Best Game               5           B          0
# 11           5        2  Best Game               6           B          0
# 12           6        2  Best Game               7           B          0
# 13           7        2  Best Game               8           B          0
# 14           8        2  Best Game               9          BB          0

# %%
poll['poll_id'].values[0]
# Out:
# 2

# %%
id=2
option=1
polls_df.loc[(polls_df['poll_id'] == int(id)) & (polls_df['poll_option_no'] == int(option)), 'poll_vote'] += 1
polls_df
# Out:
#     Unnamed: 0  poll_id             poll_name  poll_option_no  \
# 0            0        1             Best Game               1
# 1            1        1             Best Game               2
# 2            2        1             Best Game               3
# 3            3        1             Best Game               4
# 4            4        1             Best Game               5
# 5            5        1             Best Game               6
# 6            0        2             Best Game               1
# 7            1        2             Best Game               2
# 8            2        2             Best Game               3
# 9            3        2             Best Game               4
# 10           4        2             Best Game               5
# 11           5        2             Best Game               6
# 12           6        2             Best Game               7
# 13           7        2             Best Game               8
# ...
